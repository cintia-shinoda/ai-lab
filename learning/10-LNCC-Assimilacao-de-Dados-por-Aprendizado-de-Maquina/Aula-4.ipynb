# %% [markdown]
# # Aula 4 -

# %% [markdown]
# ##

# %% [markdown]
# ## Assimilação de Dados por RNA

# %% [markdown]
# ## Weather Research and Forecasting Model (WRF)
#
# Gerônimo Lemos

# %% [markdown]
# ## Assimilação de dados no modelo
#
#
# César Magno
