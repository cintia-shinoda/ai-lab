# %% [markdown]
# # Aula 1 - Conceitos Básicos de RNAs (Redes Neurais Artificiais)

# %% [markdown]
# https://youtu.be/8V7XRpB7vnk

# %% [markdown]
# ## Conceitos Básicos

# %% [markdown]
# - é um modelo computacional
# - composta por coleção de neurônios artificiais
# - cada neurônio artificial (perceptron)
