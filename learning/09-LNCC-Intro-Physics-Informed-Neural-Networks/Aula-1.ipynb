# %% [markdown]
# # Aula 1 - Introdução Teórica às Redes Neurais

# %% [markdown]
# <!-- Material: https://drive.google.com/drive/u/0/folders/157wRdKNiXikGTbA1MoxcZFSGXiytn9ZQ -->

# %% [markdown]
# ## 1. Introdução ao Aprendizado de Máquina

# %% [markdown]
# - IA: qualquer técnica que permita as máquinas imitar o comportamento humano
# - Aprendizado de Máquina: habilidade de aprender sem ser explicitamente programado para a tarefa
# - Aprendizado Profundo: extração de padrões de dados usando redes neurais

# %% [markdown]
# ```bash
# Aprendizado de Máquina
# ├─ Supervisionado
# │   ├─ Classificação
# │   └─ Regressão
# │
# ├─ Não-Supervisionado
# │   ├─ Agrupamento (*Clustering*)
#
# ```

# %% [markdown]
# ### Aprendizado Supervisionado
#
# - uso de conjunto de dados rotulados para treinar o modelo
# - Requerimentos:
#   - dados rotulados para treinamento e teste
#   - métrica para avaliar o desempenho do modelo
# - Tipos de problemas: Classificação e Regressão

# %% [markdown]
# ### Não-Supervisionado
#
# - descobrir subgrupos (exemplos similares) em um conjunto de dados sem rótulos
# - Requerimentos:
#   - dados de treinamento para treino e teste
#   - NÃO requer variável resposta

# %% [markdown]
# ### História
#
# - 1957: Perceptron de Rosenblatt
# - 1960s: Decision Tree de Hunt
# - 1969: Multilayer Perceptron de Minsky e Papert
# - 1989: Backpropagation de Rumelhart, Hinton e Williams
# - 1990s: SVM de Cortes e Vapnik
# - 1997: PINNs de Lagaris, Likas e Fotiadis
# - 2001: Random Forest de Breiman
# - 2010: ResNet, AlexNet, ...
# - 2017: Transformers de Vaswani et al.
# - 2020: ChatGPT de OpenAI

# %% [markdown]
# ### Técnicas de Aprendizado de Máquina
#
# - Naïve Bayes
# - Decision Trees
# - Support Vector Machines (SVM)
# - K-Means
# - K-Nearest Neighbors (KNN)
# - Regressão Linear e Logística
# - Random Forest
# - Gradient Boosting
# - Redes Neurais Artificiais (ANN)
# - Redes Neurais Convolucionais (CNN)
# - Redes Neurais Recorrentes (RNN)
# - Transformers
# - Physics-Informed Neural Networks (PINNs)

# %% [markdown]
# ### Aplicações de PINNs
#
# - Solução de Equações Diferenciais
#   - Problema da cavidade quadrada com a tampa deslizante
#   - Navier-Stokes
#   - Continuidade
#   - Condições de contorno

# %% [markdown]
# ## 2. Estrutura Básica de uma Rede Neural

# %% [markdown]
# ## 3. Sobre a Convergência das Redes Neurais

# %% [markdown]
# - Modelos de *deep learning* são inspirados na estrutura biológica, mas são construções matemáticas, não são cérebros artificiais
#
# - Neurônio Artificial: abstrai a sinapse através de um peso (força de conexão) e gera um valor de ativação como saída

# %% [markdown]
# ### Perceptron
#
# - função algébrica comum com entrada e saída
# - esses neurônios artificiais são dispostos ao longo de camadas que interagem entre si, criando a estrutura conhecida como Rede Neural ou *Multilayer Perceptron*

# %% [markdown]
# - Camada de Entrada
# - Camada(s) Intermediária(s) (*Hidden Layer*)
# - Camada de Saída

# %% [markdown]
# ### Arquiteturas
#
# #### MLP
# - compressão de dados, reconhecimento de padrões, visão computacional, reconhecimento de alvos de sonar, reconhecimento de fala, reconhecimento de caracteres manuscritos, PINNs, ...
#
# #### Convolucional (*Convolutional (CNN)*)
# - análise de imagens, Processamento de Linguagem Natural (PLN) e outros problemas complexos de classificação de imagens, processamento de sinais, ...
#
# #### Recorrente (*Recurrent (RNN)*)
# - reconhecimento de fala e PLN
#
#
# #### LSTM
# - usada para dados sequenciais como análise de sentimento, modelagem de linguagem, reconhecimento de fala e análise de vídeo
#
# #### Transformers

# %% [markdown]
# ### Arquiteturas nas CNN
# - AlexNet
# - ResNet
# - U-NET

# %% [markdown]
# ### Neurônio Artificial
#
# #### Entrada
# - vetor da vase de dados ou saída dos neurônios da camada anterior ($x_i$)
#
# #### Saída
# - combinação não-linear das entradas
#   - cada ligação tem um peso associado ($w_i$)
#   - cada neurônio tem um viés ($b$)
# - a saída do neurônio é dada por $\hat{y} = \sigma(\sum w_i x_i + b) = \sigma(w_1 x_1 + w_2 x_2 + w_3 x_3 + ... + b)$
#
# - um neurônio faz uma transformação afim dos dados de entrada e em seguida aplica uma função de ativação $\sigma$

# %% [markdown]
# ### Função de Ativação

# %% [markdown]
# ## 4....
